# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib

# %%
import pandas as ps #Подключение библиотек
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn import linear_model, ensemble

# %%
df = ps.read_csv('training_data.csv') #Чтение таблицы для тренировки
df
# Out:
#            id  price  year  condition  cylinders  odometer  title_status  \
# 0     1071800  43900  2016          4          6     43500             1
# 1     1458828  15490  2009          2          8     98131             1
# 2      890437   2495  2002          2          8    201803             1
# 3      463498   1300  2000          1          8    170305             0
# 4      322774  13865  2010          3          8    166062             1
# ...       ...    ...   ...        ...        ...       ...           ...
# 4908  1653880  21480  2013          3          8     64412             0
# 4909   425071      1  2014          3          6    117123             1
# 4910   589209  16500  2010          3          8     91275             1
# 4911  1486502  16000  2012          3          8    132000             1
# 4912   113769   3250  2003          2          8    239446             1
#
#       transmission  drive  size  lat  long  weather
# ...

# %%
df.hist(figsize=(15, 15 )); #Создание гистограммы

# %%
df_values=df['price'] #создание целевой переменной
df_values
# Out:
# 0       43900
# 1       15490
# 2        2495
# 3        1300
# 4       13865
#         ...
# 4908    21480
# 4909        1
# 4910    16500
# 4911    16000
# 4912     3250
# Name: price, Length: 4913, dtype: int64

# %%
df_points=df.drop('price', axis=1)
df_points
# Out:
#            id  year  condition  cylinders  odometer  title_status  \
# 0     1071800  2016          4          6     43500             1
# 1     1458828  2009          2          8     98131             1
# 2      890437  2002          2          8    201803             1
# 3      463498  2000          1          8    170305             0
# 4      322774  2010          3          8    166062             1
# ...       ...   ...        ...        ...       ...           ...
# 4908  1653880  2013          3          8     64412             0
# 4909   425071  2014          3          6    117123             1
# 4910   589209  2010          3          8     91275             1
# 4911  1486502  2012          3          8    132000             1
# 4912   113769  2003          2          8    239446             1
#
#       transmission  drive  size  lat  long  weather
# 0                1      1     1   36   -82       59
# 1                1      1     1   40   -74       52
# ...

# %%
df_points.shape #размерность
# Out:
# (4913, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4913 entries, 0 to 4912
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            4913 non-null   int64
#  1   price         4913 non-null   int64
#  2   year          4913 non-null   int64
#  3   condition     4913 non-null   int64
#  4   cylinders     4913 non-null   int64
#  5   odometer      4913 non-null   int64
#  6   title_status  4913 non-null   int64
#  7   transmission  4913 non-null   int64
#  8   drive         4913 non-null   int64
#  9   size          4913 non-null   int64
#  10  lat           4913 non-null   int64
#  11  long          4913 non-null   int64
#  12  weather       4913 non-null   int64
# dtypes: int64(13)
# memory usage: 499.1 KB

# %% [markdown]
# <h1>ТРЕНИРОВКА МОДЕЛИ<h1>

# %%
linear_regression_model=linear_model.LinearRegression() #добавляем линейную модель

# %%
random_forest_model=ensemble.RandomForestRegressor(random_state=123) #добаляем модель случайные леса

# %%
linear_regression_model.fit(df_points, df_values) #тренируем линейную модель
# Out:
# LinearRegression()

# %%
random_forest_model.fit(df_points, df_values)
# Out:
# RandomForestRegressor(random_state=123)

# %% [markdown]
# <h1>ТЕСТИРОВАНИЕ МОДЕЛЕЙ<h1>

# %%
test_data = ps.read_csv('test_data.csv')

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            62 non-null     int64
#  1   price         62 non-null     int64
#  2   year          62 non-null     int64
#  3   condition     62 non-null     int64
#  4   cylinders     62 non-null     int64
#  5   odometer      62 non-null     int64
#  6   title_status  62 non-null     int64
#  7   transmission  62 non-null     int64
#  8   drive         62 non-null     int64
#  9   size          62 non-null     int64
#  10  lat           62 non-null     int64
#  11  long          62 non-null     int64
#  12  weather       62 non-null     int64
# dtypes: int64(13)
# memory usage: 6.4 KB

# %%
test_values = test_data['price'] #создане целевой переменной

# %%
test_points = test_data.drop('price', axis=1)

# %%
list(test_points)==list(df_points)
# Out:
# True

# %%
test_predictions_linear = linear_regression_model.predict(test_points)

# %%
test_predictions_random_forest = random_forest.predict(test_points)

# %%
plt.figure(figsize=(5,5))
plt.scatter(test_values, test_predictions_linear) # рисуем точки, соответствущие парам настоящее значение - прогноз
plt.plot([0, max(test_values)], [0, max(test_predictions_linear)])  # рисуем прямую, на которой предсказания и настоящие значения совпадают
plt.xlabel('Настоящая цена', fontsize=20)
plt.ylabel('Предсказанная цена', fontsize=20);

# %%
plt.figure(figsize=(7, 7))
plt.scatter(test_values, test_predictions_random_forest) # рисуем точки, соответствущие парам настоящее значение - прогноз
plt.plot([0, max(test_values)], [0, max(test_predictions_random_forest)]) # рисуем прямую, на которой предсказания и настоящие значения совпадают
plt.xlabel('Настоящая цена', fontsize=20)
plt.ylabel('Предсказанная цена', fontsize=20);

# %% [markdown]
# <h1>ЗАКЛЮЧЕНИЯ<h1>

# %% [markdown]
# <h3>В этом ноутбуке мы научились
#
# Определять наличие пропусков в данны
# х
# Избавляться от пропусков в данн
# ых
# Строить гистограммы для возможных значений признаково<h3>
